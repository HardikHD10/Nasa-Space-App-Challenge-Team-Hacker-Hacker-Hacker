# %%
#5 yearly Script

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# Reading the dataset using the provided script with delim_whitespace=True
data4 = pd.read_csv("/content/drive/MyDrive/NASA Hackathon/Final Test Datasets Scripts/Raw Dataset/www-app3.gfz-potsdam.de_kp_index_Kp_ap_Ap_SN_F107_since_1932.txt", delim_whitespace=True)

# Extracting the column names
data4.columns
# Out:
# Index(['YYY', 'MM', 'DD', 'days', 'days_m', 'Bsr', 'dB', 'Kp1', 'Kp2', 'Kp3',
#        'Kp4', 'Kp5', 'Kp6', 'Kp7', 'Kp8', 'ap1', 'ap2', 'ap3', 'ap4', 'ap5',
#        'ap6', 'ap7', 'ap8', 'Ap', 'SN', 'F10.7obs', 'F10.7adj', 'D'],
#       dtype='object')

# %%
# Reading the provided dataset using the given script
data1 = pd.read_csv("/content/drive/MyDrive/NASA Hackathon/Final Test Datasets Scripts/Raw Dataset/rtsw_plot_data_2019-05-03T16_00_00 (1).txt", delim_whitespace=True, header=0, index_col=None)

# Combining the index (which has the date) and the "Timestamp" column (which has the time) into a single column
data1["Timestamp"] = data1.index.astype(str) + " " + data1["Timestamp"]

# Resetting the index to default integers
data1 = data1.reset_index(drop=True)

# Extracting the column names for the provided dataset
data1.columns
# Out:
# Index(['Timestamp', 'Source', 'Bt-med', 'Bt-min', 'Bt-max', 'Bx-med', 'Bx-min',
#        'Bx-max', 'By-med', 'By-min', 'By-max', 'Bz-med', 'Bz-min', 'Bz-max',
#        'Phi-mean', 'Phi-min', 'Phi-max', 'Theta-med', 'Theta-min', 'Theta-max',
#        'Dens-med', 'Dens-min', 'Dens-max', 'Speed-med', 'Speed-min',
#        'Speed-max', 'Temp-med', 'Temp-min', 'Temp-max'],
#       dtype='object')

# %%
data1
# Out:
#                 Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  Bx-min  \
# 0     2019-05-04 00:00:00       1    4.35    2.24   11.02    2.11   -4.73
# 1     2019-05-05 00:00:00       1    3.46    1.62    4.20    1.86   -3.46
# 2     2019-05-06 00:00:00       1    4.01    2.73    5.13    1.86   -2.55
# 3     2019-05-07 00:00:00       1    3.73    1.28    4.70    2.13   -1.02
# 4     2019-05-08 00:00:00       1    2.62    0.86    3.37    2.18    0.59
# ...                   ...     ...     ...     ...     ...     ...     ...
# 1443  2023-10-03 00:00:00       1    7.58    5.56    8.60   -6.37   -7.91
# 1444  2023-10-04 00:00:00       1    7.82    5.73    9.41   -3.49   -7.42
# 1445  2023-10-05 00:00:00       1    4.36    2.17    7.49    0.30   -4.48
# 1446  2023-10-06 00:00:00       1    5.98    1.76    7.95    0.61   -3.91
# 1447  2023-10-07 00:00:00       1    5.30    3.32    5.95   -1.02   -2.60
#
#       Bx-max  By-med  By-min  ...  Theta-max  Dens-med  Dens-min  Dens-max  \
# 0      10.15   -1.58   -7.00  ...      62.22      6.87      3.50      9.10
# 1       3.93   -1.51   -3.62  ...      65.63      4.22      1.27      5.85
# 2       4.80   -2.31   -4.59  ...      66.19      4.46      2.11      7.36
# 3       3.94   -0.70   -4.21  ...      53.41      4.70      2.37     11.02
# 4       3.09   -0.03   -1.08  ...      54.93      9.84      8.17     16.65
# ...      ...     ...     ...  ...        ...       ...       ...       ...
# 1443    1.71    1.70   -4.47  ...      18.12      4.37      1.76      9.68
# 1444    1.88    5.80   -1.07  ...      35.09      3.34      0.91      7.22
# 1445    4.09    1.79   -4.80  ...      72.47      5.87      4.05     13.25
# 1446    5.45    2.92   -5.43  ...      62.84     10.76      3.08     16.48
# 1447    1.90    2.56   -1.43  ...      82.01      3.70      1.10      7.19
#
#       Speed-med  Speed-min  Speed-max  Temp-med  Temp-min  Temp-max
# 0         482.0      391.5      515.4    179360     55436    303319
# 1         434.4      359.7      494.9    122091     25719    334905
# 2         374.0      322.5      392.8     43075     12791     75843
# 3         351.9      327.4      382.2     29746     11704     55111
# 4         326.4      307.4      341.5     12476      7815     16210
# ...         ...        ...        ...       ...       ...       ...
# 1443      339.3      314.3      436.6     62372     10025    209472
# 1444      407.1      328.4      474.4    121306      6533    464060
# 1445      453.0      428.9      490.0    176874     67577    242981
# 1446      418.8      375.8      475.8     61374     14814    209840
# 1447      419.6      323.2      507.0    180254      5000    336083
#
# [1448 rows x 29 columns]

# %%
# Step 1: Load the datasets
# We have already loaded the common dataset previously as data4

# Extracting the Timestamp column from data1
timestamp_column = data1["Timestamp"]

# Displaying the first few rows of the Timestamp column
timestamp_column.head()
# Out:
# 0    2019-05-04 00:00:00
# 1    2019-05-05 00:00:00
# 2    2019-05-06 00:00:00
# 3    2019-05-07 00:00:00
# 4    2019-05-08 00:00:00
# Name: Timestamp, dtype: object

# %%
# Correcting the Timestamp column to only have the datetime values
data1["Timestamp"] = pd.to_datetime(data1["Timestamp"].str.split().str[-2] + " " + data1["Timestamp"].str.split().str[-1])

# Extracting date and time separately in desired formats
data1['Date'] = data1['Timestamp'].dt.strftime('%d-%m-%Y')
data1['Time'] = data1['Timestamp'].dt.strftime('%H:%M:%S')

# Displaying the first few rows of the corrected Date and Time columns
data1[['Date', 'Time']].head()
# Out:
#          Date      Time
# 0  04-05-2019  00:00:00
# 1  05-05-2019  00:00:00
# 2  06-05-2019  00:00:00
# 3  07-05-2019  00:00:00
# 4  08-05-2019  00:00:00

# %%
data1
# Out:
#       Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  Bx-min  Bx-max  \
# 0    2019-05-04       1    4.35    2.24   11.02    2.11   -4.73   10.15
# 1    2019-05-05       1    3.46    1.62    4.20    1.86   -3.46    3.93
# 2    2019-05-06       1    4.01    2.73    5.13    1.86   -2.55    4.80
# 3    2019-05-07       1    3.73    1.28    4.70    2.13   -1.02    3.94
# 4    2019-05-08       1    2.62    0.86    3.37    2.18    0.59    3.09
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 1443 2023-10-03       1    7.58    5.56    8.60   -6.37   -7.91    1.71
# 1444 2023-10-04       1    7.82    5.73    9.41   -3.49   -7.42    1.88
# 1445 2023-10-05       1    4.36    2.17    7.49    0.30   -4.48    4.09
# 1446 2023-10-06       1    5.98    1.76    7.95    0.61   -3.91    5.45
# 1447 2023-10-07       1    5.30    3.32    5.95   -1.02   -2.60    1.90
#
#       By-med  By-min  ...  Dens-min  Dens-max  Speed-med  Speed-min  \
# 0      -1.58   -7.00  ...      3.50      9.10      482.0      391.5
# 1      -1.51   -3.62  ...      1.27      5.85      434.4      359.7
# 2      -2.31   -4.59  ...      2.11      7.36      374.0      322.5
# 3      -0.70   -4.21  ...      2.37     11.02      351.9      327.4
# 4      -0.03   -1.08  ...      8.17     16.65      326.4      307.4
# ...      ...     ...  ...       ...       ...        ...        ...
# 1443    1.70   -4.47  ...      1.76      9.68      339.3      314.3
# 1444    5.80   -1.07  ...      0.91      7.22      407.1      328.4
# 1445    1.79   -4.80  ...      4.05     13.25      453.0      428.9
# 1446    2.92   -5.43  ...      3.08     16.48      418.8      375.8
# 1447    2.56   -1.43  ...      1.10      7.19      419.6      323.2
#
#       Speed-max  Temp-med  Temp-min  Temp-max        Date      Time
# 0         515.4    179360     55436    303319  04-05-2019  00:00:00
# 1         494.9    122091     25719    334905  05-05-2019  00:00:00
# 2         392.8     43075     12791     75843  06-05-2019  00:00:00
# 3         382.2     29746     11704     55111  07-05-2019  00:00:00
# 4         341.5     12476      7815     16210  08-05-2019  00:00:00
# ...         ...       ...       ...       ...         ...       ...
# 1443      436.6     62372     10025    209472  03-10-2023  00:00:00
# 1444      474.4    121306      6533    464060  04-10-2023  00:00:00
# 1445      490.0    176874     67577    242981  05-10-2023  00:00:00
# 1446      475.8     61374     14814    209840  06-10-2023  00:00:00
# 1447      507.0    180254      5000    336083  07-10-2023  00:00:00
#
# [1448 rows x 31 columns]

# %%
# Ensure the "Date" column in both dataframes is of datetime format
data4["Date"] = pd.to_datetime(data4["YYY"].astype(str) + "-" + data4["MM"].astype(str).str.zfill(2) + "-" + data4["DD"].astype(str).str.zfill(2))
data1["Date"] = pd.to_datetime(data1["Date"])

# Merge the specified columns from data4 into data1 based on the "Date" column
merged_data = pd.merge(data1, data4[['Date', 'Ap', 'SN', 'F10.7obs', 'F10.7adj']], on='Date', how='left')
# Out:
# <ipython-input-62-827bf2e107ca>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data1["Date"] = pd.to_datetime(data1["Date"])

# %%
merged_data
# Out:
#       Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  Bx-min  Bx-max  \
# 0    2019-05-04       1    4.35    2.24   11.02    2.11   -4.73   10.15
# 1    2019-05-05       1    3.46    1.62    4.20    1.86   -3.46    3.93
# 2    2019-05-06       1    4.01    2.73    5.13    1.86   -2.55    4.80
# 3    2019-05-07       1    3.73    1.28    4.70    2.13   -1.02    3.94
# 4    2019-05-08       1    2.62    0.86    3.37    2.18    0.59    3.09
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 1443 2023-10-03       1    7.58    5.56    8.60   -6.37   -7.91    1.71
# 1444 2023-10-04       1    7.82    5.73    9.41   -3.49   -7.42    1.88
# 1445 2023-10-05       1    4.36    2.17    7.49    0.30   -4.48    4.09
# 1446 2023-10-06       1    5.98    1.76    7.95    0.61   -3.91    5.45
# 1447 2023-10-07       1    5.30    3.32    5.95   -1.02   -2.60    1.90
#
#       By-med  By-min  ...  Speed-max  Temp-med  Temp-min  Temp-max       Date  \
# 0      -1.58   -7.00  ...      515.4    179360     55436    303319 2019-04-05
# 1      -1.51   -3.62  ...      494.9    122091     25719    334905 2019-05-05
# 2      -2.31   -4.59  ...      392.8     43075     12791     75843 2019-06-05
# 3      -0.70   -4.21  ...      382.2     29746     11704     55111 2019-07-05
# 4      -0.03   -1.08  ...      341.5     12476      7815     16210 2019-08-05
# ...      ...     ...  ...        ...       ...       ...       ...        ...
# 1443    1.70   -4.47  ...      436.6     62372     10025    209472 2023-03-10
# 1444    5.80   -1.07  ...      474.4    121306      6533    464060 2023-04-10
# 1445    1.79   -4.80  ...      490.0    176874     67577    242981 2023-05-10
# 1446    2.92   -5.43  ...      475.8     61374     14814    209840 2023-06-10
# 1447    2.56   -1.43  ...      507.0    180254      5000    336083 2023-07-10
#
#           Time    Ap     SN  F10.7obs  F10.7adj
# 0     00:00:00  12.0    5.0      71.7      71.8
# 1     00:00:00   3.0   12.0      73.5      74.7
# 2     00:00:00   4.0    0.0      69.8      71.8
# 3     00:00:00   4.0    0.0      66.8      69.0
# 4     00:00:00  34.0    8.0      68.1      70.1
# ...        ...   ...    ...       ...       ...
# 1443  00:00:00   9.0  148.0     171.2     168.8
# 1444  00:00:00  12.0   89.0     139.8     140.3
# 1445  00:00:00  24.0  165.0     170.1     173.4
# 1446  00:00:00   4.0  168.0     161.2     166.1
# 1447  00:00:00   4.0  191.0     190.6     196.9
#
# [1448 rows x 35 columns]

# %%
merged_data['ap'] = merged_data['Ap']

# %%
merged_data
# Out:
#       Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  Bx-min  Bx-max  \
# 0    2019-05-04       1    4.35    2.24   11.02    2.11   -4.73   10.15
# 1    2019-05-05       1    3.46    1.62    4.20    1.86   -3.46    3.93
# 2    2019-05-06       1    4.01    2.73    5.13    1.86   -2.55    4.80
# 3    2019-05-07       1    3.73    1.28    4.70    2.13   -1.02    3.94
# 4    2019-05-08       1    2.62    0.86    3.37    2.18    0.59    3.09
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 1443 2023-10-03       1    7.58    5.56    8.60   -6.37   -7.91    1.71
# 1444 2023-10-04       1    7.82    5.73    9.41   -3.49   -7.42    1.88
# 1445 2023-10-05       1    4.36    2.17    7.49    0.30   -4.48    4.09
# 1446 2023-10-06       1    5.98    1.76    7.95    0.61   -3.91    5.45
# 1447 2023-10-07       1    5.30    3.32    5.95   -1.02   -2.60    1.90
#
#       By-med  By-min  ...  Temp-med  Temp-min  Temp-max       Date      Time  \
# 0      -1.58   -7.00  ...    179360     55436    303319 2019-04-05  00:00:00
# 1      -1.51   -3.62  ...    122091     25719    334905 2019-05-05  00:00:00
# 2      -2.31   -4.59  ...     43075     12791     75843 2019-06-05  00:00:00
# 3      -0.70   -4.21  ...     29746     11704     55111 2019-07-05  00:00:00
# 4      -0.03   -1.08  ...     12476      7815     16210 2019-08-05  00:00:00
# ...      ...     ...  ...       ...       ...       ...        ...       ...
# 1443    1.70   -4.47  ...     62372     10025    209472 2023-03-10  00:00:00
# 1444    5.80   -1.07  ...    121306      6533    464060 2023-04-10  00:00:00
# 1445    1.79   -4.80  ...    176874     67577    242981 2023-05-10  00:00:00
# 1446    2.92   -5.43  ...     61374     14814    209840 2023-06-10  00:00:00
# 1447    2.56   -1.43  ...    180254      5000    336083 2023-07-10  00:00:00
#
#         Ap     SN  F10.7obs  F10.7adj    ap
# 0     12.0    5.0      71.7      71.8  12.0
# 1      3.0   12.0      73.5      74.7   3.0
# 2      4.0    0.0      69.8      71.8   4.0
# 3      4.0    0.0      66.8      69.0   4.0
# 4     34.0    8.0      68.1      70.1  34.0
# ...    ...    ...       ...       ...   ...
# 1443   9.0  148.0     171.2     168.8   9.0
# 1444  12.0   89.0     139.8     140.3  12.0
# 1445  24.0  165.0     170.1     173.4  24.0
# 1446   4.0  168.0     161.2     166.1   4.0
# 1447   4.0  191.0     190.6     196.9   4.0
#
# [1448 rows x 36 columns]

# %%
data = merged_data.drop(["Ap"],axis=1)

# %%
# Replace NaN values with group median
for column in data.columns:
    if data[column].dtype != 'object':
        data[column].fillna(data[column].median(), inplace=True)

# %%
data
# Out:
#       Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  Bx-min  Bx-max  \
# 0    2019-05-04       1    4.35    2.24   11.02    2.11   -4.73   10.15
# 1    2019-05-05       1    3.46    1.62    4.20    1.86   -3.46    3.93
# 2    2019-05-06       1    4.01    2.73    5.13    1.86   -2.55    4.80
# 3    2019-05-07       1    3.73    1.28    4.70    2.13   -1.02    3.94
# 4    2019-05-08       1    2.62    0.86    3.37    2.18    0.59    3.09
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 1443 2023-10-03       1    7.58    5.56    8.60   -6.37   -7.91    1.71
# 1444 2023-10-04       1    7.82    5.73    9.41   -3.49   -7.42    1.88
# 1445 2023-10-05       1    4.36    2.17    7.49    0.30   -4.48    4.09
# 1446 2023-10-06       1    5.98    1.76    7.95    0.61   -3.91    5.45
# 1447 2023-10-07       1    5.30    3.32    5.95   -1.02   -2.60    1.90
#
#       By-med  By-min  ...  Speed-max  Temp-med  Temp-min  Temp-max       Date  \
# 0      -1.58   -7.00  ...      515.4    179360     55436    303319 2019-04-05
# 1      -1.51   -3.62  ...      494.9    122091     25719    334905 2019-05-05
# 2      -2.31   -4.59  ...      392.8     43075     12791     75843 2019-06-05
# 3      -0.70   -4.21  ...      382.2     29746     11704     55111 2019-07-05
# 4      -0.03   -1.08  ...      341.5     12476      7815     16210 2019-08-05
# ...      ...     ...  ...        ...       ...       ...       ...        ...
# 1443    1.70   -4.47  ...      436.6     62372     10025    209472 2023-03-10
# 1444    5.80   -1.07  ...      474.4    121306      6533    464060 2023-04-10
# 1445    1.79   -4.80  ...      490.0    176874     67577    242981 2023-05-10
# 1446    2.92   -5.43  ...      475.8     61374     14814    209840 2023-06-10
# 1447    2.56   -1.43  ...      507.0    180254      5000    336083 2023-07-10
#
#           Time     SN  F10.7obs  F10.7adj    ap
# 0     00:00:00    5.0      71.7      71.8  12.0
# 1     00:00:00   12.0      73.5      74.7   3.0
# 2     00:00:00    0.0      69.8      71.8   4.0
# 3     00:00:00    0.0      66.8      69.0   4.0
# 4     00:00:00    8.0      68.1      70.1  34.0
# ...        ...    ...       ...       ...   ...
# 1443  00:00:00  148.0     171.2     168.8   9.0
# 1444  00:00:00   89.0     139.8     140.3  12.0
# 1445  00:00:00  165.0     170.1     173.4  24.0
# 1446  00:00:00  168.0     161.2     166.1   4.0
# 1447  00:00:00  191.0     190.6     196.9   4.0
#
# [1448 rows x 35 columns]

# %%
import numpy as np

# %%
data.columns
# Out:
# Index(['Timestamp', 'Source', 'Bt-med', 'Bt-min', 'Bt-max', 'Bx-med', 'Bx-min',
#        'Bx-max', 'By-med', 'By-min', 'By-max', 'Bz-med', 'Bz-min', 'Bz-max',
#        'Phi-mean', 'Phi-min', 'Phi-max', 'Theta-med', 'Theta-min', 'Theta-max',
#        'Dens-med', 'Dens-min', 'Dens-max', 'Speed-med', 'Speed-min',
#        'Speed-max', 'Temp-med', 'Temp-min', 'Temp-max', 'Date', 'Time', 'SN',
#        'F10.7obs', 'F10.7adj', 'ap'],
#       dtype='object')

# %%
# List of numerical columns based on the provided columns
numerical_columns = ['Bt-med', 'Bt-min', 'Bt-max', 'Bx-med', 'Bx-min',
                     'Bx-max', 'By-med', 'By-min', 'By-max', 'Bz-med', 'Bz-min', 'Bz-max',
                     'Phi-mean', 'Phi-min', 'Phi-max', 'Theta-med', 'Theta-min', 'Theta-max',
                     'Dens-med', 'Dens-min', 'Dens-max', 'Speed-med', 'Speed-min',
                     'Speed-max', 'Temp-med', 'Temp-min', 'Temp-max', 'SN',
                     'F10.7obs', 'F10.7adj', 'ap']

# Replace outliers based on the 25th and 75th quantiles
for column in numerical_columns:
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    data[column] = np.where(data[column] < Q1, Q1, data[column])
    data[column] = np.where(data[column] > Q3, Q3, data[column])

# %%
data
# Out:
#       Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  Bx-min  Bx-max  \
# 0    2019-05-04       1    4.35    2.24  9.6525  2.1100 -4.7300  5.9200
# 1    2019-05-05       1    3.91    1.87  5.4875  1.8600 -3.4600  3.9300
# 2    2019-05-06       1    4.01    2.73  5.4875  1.8600 -2.7775  4.8000
# 3    2019-05-07       1    3.91    1.87  5.4875  2.1300 -2.7775  3.9400
# 4    2019-05-08       1    3.91    1.87  5.4875  2.1800 -2.7775  3.0900
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 1443 2023-10-03       1    6.26    4.02  8.6000 -2.3725 -5.7525  2.9175
# 1444 2023-10-04       1    6.26    4.02  9.4100 -2.3725 -5.7525  2.9175
# 1445 2023-10-05       1    4.36    2.17  7.4900  0.3000 -4.4800  4.0900
# 1446 2023-10-06       1    5.98    1.87  7.9500  0.6100 -3.9100  5.4500
# 1447 2023-10-07       1    5.30    3.32  5.9500 -1.0200 -2.7775  2.9175
#
#       By-med  By-min  ...  Speed-max  Temp-med  Temp-min   Temp-max  \
# 0    -1.5800 -6.8950  ...      515.4  179360.0  55436.00  303319.00
# 1    -1.5100 -3.6200  ...      494.9  122091.0  25719.00  334905.00
# 2    -2.3100 -4.5900  ...      392.8   43075.0  12791.00  110504.50
# 3    -0.7000 -4.2100  ...      384.7   34110.0  11704.00  110504.50
# 4    -0.0300 -3.3375  ...      384.7   34110.0  10265.25  110504.50
# ...      ...     ...  ...        ...       ...       ...        ...
# 1443  1.7000 -4.4700  ...      436.6   62372.0  10265.25  209472.00
# 1444  1.9825 -3.3375  ...      474.4  121306.0  10265.25  461707.25
# 1445  1.7900 -4.8000  ...      490.0  176874.0  66216.25  242981.00
# 1446  1.9825 -5.4300  ...      475.8   61374.0  14814.00  209840.00
# 1447  1.9825 -3.3375  ...      507.0  180254.0  10265.25  336083.00
#
#            Date      Time    SN  F10.7obs  F10.7adj  Max_ap
# 0    2019-04-05  00:00:00   8.0      72.5    72.575    10.0
# 1    2019-05-05  00:00:00  12.0      73.5    74.700     4.0
# 2    2019-06-05  00:00:00   8.0      72.5    72.575     4.0
# 3    2019-07-05  00:00:00   8.0      72.5    72.575     4.0
# 4    2019-08-05  00:00:00   8.0      72.5    72.575    10.0
# ...         ...       ...   ...       ...       ...     ...
# 1443 2023-03-10  00:00:00  94.0     134.5   134.025     9.0
# 1444 2023-04-10  00:00:00  89.0     134.5   134.025    10.0
# 1445 2023-05-10  00:00:00  94.0     134.5   134.025    10.0
# 1446 2023-06-10  00:00:00  94.0     134.5   134.025     4.0
# 1447 2023-07-10  00:00:00  94.0     134.5   134.025     4.0
#
# [1448 rows x 35 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Standard scaling on the numerical columns
scaler = StandardScaler()
data[numerical_columns] = scaler.fit_transform(data[numerical_columns])

# %%
data
# Out:
#       Timestamp  Source    Bt-med    Bt-min    Bt-max    Bx-med    Bx-min  \
# 0    2019-05-04       1 -0.705818 -0.758417  1.314930  1.020820 -0.433711
# 1    2019-05-05       1 -1.164205 -1.181769 -1.135791  0.895139  0.629441
# 2    2019-05-06       1 -1.060026 -0.197761 -1.135791  0.895139  1.199211
# 3    2019-05-07       1 -1.164205 -1.181769 -1.135791  1.030874  1.199211
# 4    2019-05-08       1 -1.164205 -1.181769 -1.135791  1.056010  1.199211
# ...         ...     ...       ...       ...       ...       ...       ...
# 1443 2023-10-03       1  1.283996  1.278251  0.696176 -1.231687 -1.288104
# 1444 2023-10-04       1  1.283996  1.278251  1.173216 -1.231687 -1.288104
# 1445 2023-10-05       1 -0.695401 -0.838511  0.042454  0.110894 -0.224429
# 1446 2023-10-06       1  0.992296 -1.181769  0.313366  0.266738  0.252734
# 1447 2023-10-07       1  0.283880  0.477315 -0.864512 -0.552699  1.199211
#
#         Bx-max    By-med    By-min  ...  Speed-max  Temp-med  Temp-min  \
# 0     1.255622 -0.709521 -1.298725  ...   0.911643  1.092869  0.958716
# 1    -0.392050 -0.671126  0.973131  ...   0.570014  0.242691 -0.308534
# 2     0.328289 -1.109925  0.299474  ...  -1.131467 -0.930330 -0.859836
# 3    -0.383770 -0.226842  0.563381  ...  -1.266452 -1.063062 -0.906190
# 4    -1.087550  0.140653  1.168023  ...  -1.266452 -1.063062 -0.967392
# ...        ...       ...       ...  ...        ...       ...       ...
# 1443 -1.228823  1.089556  0.382813  ...  -0.401547 -0.643859 -0.967392
# 1444 -1.228823  1.243479  1.168023  ...   0.228385  0.231037 -0.967392
# 1445 -0.259574  1.138921  0.153631  ...   0.488356  1.055963  1.416726
# 1446  0.866474  1.243479 -0.283899  ...   0.251715 -0.658675 -0.773567
# 1447 -1.228823  1.243479  1.168023  ...   0.771659  1.106141 -0.967392
#
#       Temp-max       Date      Time        SN  F10.7obs  F10.7adj        ap
# 0     0.180315 2019-04-05  00:00:00 -1.082293 -1.004307 -1.003843  1.376821
# 1     0.399381 2019-05-05  00:00:00 -0.970295 -0.965975 -0.922311 -1.028532
# 2    -1.156951 2019-06-05  00:00:00 -1.082293 -1.004307 -1.003843 -1.028532
# 3    -1.156951 2019-07-05  00:00:00 -1.082293 -1.004307 -1.003843 -1.028532
# 4    -1.156951 2019-08-05  00:00:00 -1.082293 -1.004307 -1.003843  1.376821
# ...        ...        ...       ...       ...       ...       ...       ...
# 1443 -0.470565 2023-03-10  00:00:00  1.325665  1.372304  1.373419  0.975929
# 1444  1.278261 2023-04-10  00:00:00  1.185667  1.372304  1.373419  1.376821
# 1445 -0.238162 2023-05-10  00:00:00  1.325665  1.372304  1.373419  1.376821
# 1446 -0.468013 2023-06-10  00:00:00  1.325665  1.372304  1.373419 -1.028532
# 1447  0.407551 2023-07-10  00:00:00  1.325665  1.372304  1.373419 -1.028532
#
# [1448 rows x 35 columns]

# %%
# Extracting the specified columns to finalize the X_data
X_data = data[['Date', 'Time', 'ap', 'SN', 'Bt-med', 'Bt-min', 'Bt-max', 'Bx-med', 'Bx-min', 'Bx-max',
       'By-med', 'By-min', 'By-max', 'Bz-min', 'Bz-max', 'Phi-mean', 'Phi-min',
       'Phi-max', 'Theta-med', 'Theta-min', 'Theta-max', 'Dens-med',
       'Dens-min', 'Dens-max', 'Speed-max', 'Temp-med', 'Temp-min',
       'Temp-max']]

# Displaying the first few rows of the finalized X_data
X_data.head()
# Out:
#         Date      Time        ap        SN    Bt-med    Bt-min    Bt-max  \
# 0 2019-04-05  00:00:00  1.376821 -1.082293 -0.705818 -0.758417  1.314930
# 1 2019-05-05  00:00:00 -1.028532 -0.970295 -1.164205 -1.181769 -1.135791
# 2 2019-06-05  00:00:00 -1.028532 -1.082293 -1.060026 -0.197761 -1.135791
# 3 2019-07-05  00:00:00 -1.028532 -1.082293 -1.164205 -1.181769 -1.135791
# 4 2019-08-05  00:00:00  1.376821 -1.082293 -1.164205 -1.181769 -1.135791
#
#      Bx-med    Bx-min    Bx-max  ...  Theta-med  Theta-min  Theta-max  \
# 0  1.020820 -0.433711  1.255622  ...  -1.021485  -0.978693   0.230897
# 1  0.895139  0.629441 -0.392050  ...   0.416794   1.317047   0.568232
# 2  0.895139  1.199211  0.328289  ...  -0.804387   1.012299   0.623630
# 3  1.030874  1.199211 -0.383770  ...  -1.158257  -0.782593  -0.640632
# 4  1.056010  1.199211 -1.087550  ...   1.247467   1.317047  -0.490266
#
#    Dens-med  Dens-min  Dens-max  Speed-max  Temp-med  Temp-min  Temp-max
# 0  0.000932  0.015029 -0.964223   0.911643  1.092869  0.958716  0.180315
# 1 -1.193434 -1.244907 -1.173535   0.570014  0.242691 -0.308534  0.399381
# 2 -1.193434 -1.046372 -1.173535  -1.131467 -0.930330 -0.859836 -1.156951
# 3 -1.193434 -0.847836 -0.407023  -1.266452 -1.063062 -0.906190 -1.156951
# 4  1.273796  1.252058  1.226849  -1.266452 -1.063062 -0.967392 -1.156951
#
# [5 rows x 28 columns]

# %%
# Verifying the presence and non-null counts of the specified columns in X_data
column_verification = X_data[['ap', 'SN', 'Bt-med', 'Bt-min', 'Bt-max', 'Bx-med', 'Bx-min', 'Bx-max',
       'By-med', 'By-min', 'By-max', 'Bz-min', 'Bz-max', 'Phi-mean', 'Phi-min',
       'Phi-max', 'Theta-med', 'Theta-min', 'Theta-max', 'Dens-med',
       'Dens-min', 'Dens-max', 'Speed-max', 'Temp-med', 'Temp-min',
       'Temp-max']].info()

column_verification
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1448 entries, 0 to 1447
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ap         1448 non-null   float64
#  1   SN         1448 non-null   float64
#  2   Bt-med     1448 non-null   float64
#  3   Bt-min     1448 non-null   float64
#  4   Bt-max     1448 non-null   float64
#  5   Bx-med     1448 non-null   float64
#  6   Bx-min     1448 non-null   float64
#  7   Bx-max     1448 non-null   float64
#  8   By-med     1448 non-null   float64
#  9   By-min     1448 non-null   float64
#  10  By-max     1448 non-null   float64
#  11  Bz-min     1448 non-null   float64
#  12  Bz-max     1448 non-null   float64
#  13  Phi-mean   1448 non-null   float64
#  14  Phi-min    1448 non-null   float64
#  15  Phi-max    1448 non-null   float64
#  16  Theta-med  1448 non-null   float64
#  17  Theta-min  1448 non-null   float64
#  18  Theta-max  1448 non-null   float64
#  19  Dens-med   1448 non-null   float64
#  20  Dens-min   1448 non-null   float64
#  21  Dens-max   1448 non-null   float64
#  22  Speed-max  1448 non-null   float64
#  23  Temp-med   1448 non-null   float64
#  24  Temp-min   1448 non-null   float64
#  25  Temp-max   1448 non-null   float64
# dtypes: float64(26)
# memory usage: 305.4 KB

# %%
# Reordering the columns in X_data according to the specified sequence
ordered_columns = ['ap', 'SN', 'Bt-med', 'Bt-min', 'Bt-max', 'Bx-med', 'Bx-min', 'Bx-max',
       'By-med', 'By-min', 'By-max', 'Bz-min', 'Bz-max', 'Phi-mean', 'Phi-min',
       'Phi-max', 'Theta-med', 'Theta-min', 'Theta-max', 'Dens-med',
       'Dens-min', 'Dens-max', 'Speed-max', 'Temp-med', 'Temp-min',
       'Temp-max']

X_data = X_data[['Date', 'Time'] + ordered_columns]

# Displaying the first few rows of the reordered X_data
X_data.head()
# Out:
#         Date      Time        ap        SN    Bt-med    Bt-min    Bt-max  \
# 0 2019-04-05  00:00:00  1.376821 -1.082293 -0.705818 -0.758417  1.314930
# 1 2019-05-05  00:00:00 -1.028532 -0.970295 -1.164205 -1.181769 -1.135791
# 2 2019-06-05  00:00:00 -1.028532 -1.082293 -1.060026 -0.197761 -1.135791
# 3 2019-07-05  00:00:00 -1.028532 -1.082293 -1.164205 -1.181769 -1.135791
# 4 2019-08-05  00:00:00  1.376821 -1.082293 -1.164205 -1.181769 -1.135791
#
#      Bx-med    Bx-min    Bx-max  ...  Theta-med  Theta-min  Theta-max  \
# 0  1.020820 -0.433711  1.255622  ...  -1.021485  -0.978693   0.230897
# 1  0.895139  0.629441 -0.392050  ...   0.416794   1.317047   0.568232
# 2  0.895139  1.199211  0.328289  ...  -0.804387   1.012299   0.623630
# 3  1.030874  1.199211 -0.383770  ...  -1.158257  -0.782593  -0.640632
# 4  1.056010  1.199211 -1.087550  ...   1.247467   1.317047  -0.490266
#
#    Dens-med  Dens-min  Dens-max  Speed-max  Temp-med  Temp-min  Temp-max
# 0  0.000932  0.015029 -0.964223   0.911643  1.092869  0.958716  0.180315
# 1 -1.193434 -1.244907 -1.173535   0.570014  0.242691 -0.308534  0.399381
# 2 -1.193434 -1.046372 -1.173535  -1.131467 -0.930330 -0.859836 -1.156951
# 3 -1.193434 -0.847836 -0.407023  -1.266452 -1.063062 -0.906190 -1.156951
# 4  1.273796  1.252058  1.226849  -1.266452 -1.063062 -0.967392 -1.156951
#
# [5 rows x 28 columns]

# %%
# Saving the X_data DataFrame as "5year.csv"
file_path = "/content/drive/MyDrive/NASA Hackathon/Final Test Datasets Scripts/5year.csv"
X_data.to_csv(file_path, index=False)

file_path
# Out:
# '/content/drive/MyDrive/NASA Hackathon/Final Test Datasets Scripts/5year.csv'
